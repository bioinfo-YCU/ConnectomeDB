# %%
import requests
import pandas as pd
import numpy as np
import sys
import os 

sys.path.append(os.path.abspath("src"))  # Add src directory to path
from createDataTable import gene_pair0

# Get all unique genes
ligand_list = gene_pair0["Ligand"].tolist()
receptor_list = gene_pair0["Receptor"].tolist()
unique_genes = list(set(ligand_list + receptor_list))  # Combine and remove duplicates
len(unique_genes)

connectomeDB = pd.read_table("data/connectome_j.tsv", sep="\t")

#connectomeDB = connectomeDB[connectomeDB["Taxon"]== "Human"]
connectomeDB = connectomeDB.drop(columns=["Localization", "Taxon"] + [col for col in connectomeDB.columns if col.startswith("F5_")])
old_gene_symbols=set(connectomeDB['ApprovedSymbol'].unique())
intersection = pd.Series(list(old_gene_symbols.intersection(unique_genes)))
len(intersection)
len(old_gene_symbols)
# Out:
# 17263

# %%
old_gene_symbols = list(old_gene_symbols)
#old_gene_symbols = old_gene_symbols[:100]
old_gene_symbols
# Out:
# ['CTSV',
#  'HIST1H2BI',
#  'BNC2',
#  'C9orf135',
#  'GIPC3',
#  'PUS7',
#  'KCTD16',
#  'TGM3',
#  'CDC42EP4',
#  'NPR1',
#  'ZNF132',
#  'ATPAF1',
#  'ST6GALNAC2',
#  'FOXO6',
#  'BDH1',
#  'PM20D1',
#  'CDHR4',
#  'SRRM2',
#  'SNX2',
#  'TMEM169',
#  'KNOP1',
#  'SENP1',
#  'SPEF2',
#  'CYB5RL',
#  'ADAM15',
#  'GRM5',
#  'CCDC89',
#  'LGALS12',
#  'TRIM7',
#  'MCUR1',
#  'FAM65C',
#  'FRMD1',
#  'PPP1R12C',
#  'SYBU',
#  'MAP7D3',
#  'SCAF8',
#  'TXNDC15',
#  'FHL1',
#  'RDH10',
#  'TSPAN5',
#  'RPL14',
#  'DRAP1',
#  'SLC25A13',
#  'MAP7',
#  'MYOZ3',
#  'ANKFN1',
#  'OTX2',
#  'ANKRD31',
#  'WAS',
#  'CTRC',
#  'C7orf62',
#  'DHFR',
#  'ENPP2',
#  'POC1A',
#  'SNAPC1',
#  'TMEM52',
#  'ZKSCAN4',
#  'ATP6V1G1',
#  'MDGA2',
#  'NT5DC1',
#  'ZNF365',
#  'METTL9',
#  'IZUMO2',
#  'ZNF678',
#  'DNASE2',
#  'RBM24',
#  'CABYR',
#  'ELP5',
#  'ASCL1',
#  'QTRT1',
#  'FCN1',
#  'IL24',
#  'KSR2',
#  'STK17B',
#  'ACTBL2',
#  'SYT15',
#  'VARS2',
#  'LATS2',
#  'LIPI',
#  'PRMT2',
#  'ANKRD1',
#  'EDN1',
#  'C8orf4',
#  'POP7',
#  'WBSCR27',
#  'ADSSL1',
#  'TOMM20L',
#  'BCAT1',
#  'EFCAB4B',
#  'STK16',
#  'CLDN3',
#  'TMEM202',
#  'KDSR',
#  'GAL3ST4',
#  'MCM4',
#  'IPO5',
#  'GIPC2',
#  'SUPT6H',
#  'RTKN2',
#  'LENG8',
#  'C11orf86',
#  'TNKS2',
#  'TNS1',
#  'SOWAHB',
#  'CNNM3',
#  'VMP1',
#  'WNK4',
#  'GPAM',
#  'JUND',
#  'SMARCD1',
#  'AFAP1L2',
#  'TPX2',
#  'HSBP1L1',
#  'C1orf189',
#  'MAP3K14',
#  'NEU1',
#  'PDE8B',
#  'NLRP7',
#  'HLA-DPB1',
#  'MLC1',
#  'AKR1B1',
#  'GH2',
#  'GCFC2',
#  'MRPS16',
#  'CCNT2',
#  'MEDAG',
#  'COG1',
#  'COMMD1',
#  'PIEZO2',
#  'TACC1',
#  'ZC3H3',
#  'SYNJ2BP',
#  'TUBB2A',
#  'FAM105A',
#  'TRAPPC3L',
#  'OSBPL11',
#  'MAP3K8',
#  'UBR5',
#  'GNAI2',
#  'ATG14',
#  'OSBPL2',
#  'APPL1',
#  'ANKDD1A',
#  'DACT2',
#  'ELOVL1',
#  'GALNT18',
#  'SLC30A10',
#  'ST6GAL2',
#  'THBD',
#  'TRIB3',
#  'WSB1',
#  'AMPD2',
#  'MAP7D2',
#  'TERF2IP',
#  'GYG1',
#  'BEND6',
#  'ELK1',
#  'RPP40',
#  'ARIH2OS',
#  'SLC25A34',
#  'RASSF4',
#  'STX10',
#  'TMEM170A',
#  'KNSTRN',
#  'NOC3L',
#  'ZNF512',
#  'P2RX3',
#  'BSG',
#  'GOLGA8B',
#  'SLC26A2',
#  'CST5',
#  'MEX3A',
#  'LSM5',
#  'VILL',
#  'ARHGAP40',
#  'F5',
#  'TIAM2',
#  'CCR1',
#  'DLGAP2',
#  'HIST1H4L',
#  'DHCR7',
#  'APOC4',
#  'PF4V1',
#  'WFDC9',
#  'NDRG3',
#  'NID1',
#  'C12orf61',
#  'CD300LB',
#  'DNLZ',
#  'FSIP1',
#  'BRSK1',
#  'TSNARE1',
#  'BGLAP',
#  'ZNF451',
#  'GNB1',
#  'ITM2A',
#  'CACNA2D4',
#  'KIF20B',
#  'SMR3A',
#  'FAM25B',
#  'CNNM2',
#  'GALK1',
#  'CSRP2BP',
#  'MAFG',
#  'DPH6',
#  'NIPSNAP3A',
#  'RSPH6A',
#  'FAM83F',
#  'EDNRA',
#  'CNR2',
#  'PRMT1',
#  'PTK2',
#  'TMEM95',
#  'NEK6',
#  'UNC13D',
#  'CSAG1',
#  'BSPRY',
#  'FOXA1',
#  'KCTD3',
#  'RPL29',
#  'GPNMB',
#  'ZNF462',
#  'TPR',
#  'LRIG3',
#  'EHBP1L1',
#  'SSUH2',
#  'ATP8A2',
#  'BCDIN3D',
#  'LHPP',
#  'SPRR2D',
#  'DPM2',
#  'EXOSC1',
#  'TFPI2',
#  'PAQR5',
#  'LUZP1',
#  'SNX4',
#  'ZBTB40',
#  'PEBP4',
#  'MAPT',
#  'RRAGB',
#  'SERINC3',
#  'SPAG9',
#  'MOCOS',
#  'NTS',
#  'C2orf53',
#  'CYP51A1',
#  'NUSAP1',
#  'RSBN1',
#  'ITGA8',
#  'S100A16',
#  'RBM15B',
#  'XYLT2',
#  'ALDH18A1',
#  'MARCH8',
#  'SLC16A13',
#  'LIFR',
#  'CAMK1D',
#  'CHIT1',
#  'SMOX',
#  'VPS13A',
#  'CCDC59',
#  'ATP5S',
#  'TSPY4',
#  'CACNB1',
#  'ECE2',
#  'BHLHE22',
#  'EPS8L3',
#  'TRIM41',
#  'RBM20',
#  'KMT2C',
#  'RCBTB2',
#  'SEMA3C',
#  'NOXO1',
#  'VPS16',
#  'TM4SF4',
#  'POU3F2',
#  'C11orf54',
#  'LCE1A',
#  'PTPN3',
#  'LYPD1',
#  'NANS',
#  'HAVCR2',
#  'CABS1',
#  'DDX17',
#  'BAIAP2',
#  'C16orf62',
#  'CDCA8',
#  'POLR3H',
#  'TMEM69',
#  'SURF2',
#  'GFAP',
#  'GSX1',
#  'ZBTB32',
#  'OTOF',
#  'AQR',
#  'MST1',
#  'CXCL3',
#  'ZNF85',
#  'SNCB',
#  'HIST1H1C',
#  'SLC22A18',
#  'CBY1',
#  'VWCE',
#  'SLC38A5',
#  'ARPP19',
#  'TPPP',
#  'COA3',
#  'FGGY',
#  'MARK4',
#  'MLKL',
#  'C11orf21',
#  'DNAJC24',
#  'LHX5',
#  'RREB1',
#  'NBL1',
#  'ZNF329',
#  'AUH',
#  'DDIT4',
#  'DIABLO',
#  'SSH1',
#  'LONRF2',
#  'MAGED1',
#  'NCOA1',
#  'CEACAM18',
#  'PPIL1',
#  'PNPLA4',
#  'DEFA6',
#  'CHMP1B',
#  'TOMM70A',
#  'FAM26D',
#  'ATP8B2',
#  'RAB6C',
#  'COL6A3',
#  'VPS13D',
#  'KRTAP6-1',
#  'PXK',
#  'RABEP2',
#  'HIST1H2BJ',
#  'ID4',
#  'USO1',
#  'TECPR2',
#  'TRIT1',
#  'TUBD1',
#  'KCNJ10',
#  'RAPGEF1',
#  'SEC61A2',
#  'CHRNA2',
#  'C2orf73',
#  'PUS3',
#  'TSPAN11',
#  'MRPL21',
#  'GSTM5',
#  'NEUROD4',
#  'ASB9',
#  'ATP2A2',
#  'CYTIP',
#  'THRSP',
#  'ALPL',
#  'MGAT4A',
#  'LIPF',
#  'ADI1',
#  'CADM2',
#  'DTWD1',
#  'GLI1',
#  'MSTO1',
#  'FAM24B',
#  'NOTUM',
#  'CEACAM21',
#  'GNAZ',
#  'PPP1R16B',
#  'SRPR',
#  'KLF17',
#  'GPR160',
#  'PDCD4',
#  'PSMD2',
#  'SHFM1',
#  'BABAM1',
#  'MYH3',
#  'NAIF1',
#  'NDST4',
#  'PODN',
#  'SLC7A2',
#  'HERC6',
#  'ZNF443',
#  'TMEM116',
#  'NYX',
#  'C19orf57',
#  'AMN',
#  'SEZ6L2',
#  'LPL',
#  'AKNA',
#  'CA14',
#  'AMER2',
#  'S100A14',
#  'HAP1',
#  'IL17REL',
#  'INSL3',
#  'SLC12A9',
#  'SEMA3D',
#  'TOMM7',
#  'ACP6',
#  'TSPAN15',
#  'ZNF205',
#  'SEPT5',
#  'AKAP14',
#  'ITGA11',
#  'TRIM23',
#  'FIS1',
#  'KRT13',
#  'PPP1R26',
#  'SRFBP1',
#  'ZNF14',
#  'DACT3',
#  'CATSPER2',
#  'AQP9',
#  'DEGS2',
#  'HDDC2',
#  'RNF217',
#  'GALNT11',
#  'NCAM1',
#  'SEPHS2',
#  'ARHGEF37',
#  'PITX2',
#  'PPP6R3',
#  'GATC',
#  'NFS1',
#  'PSME1',
#  'ACOX3',
#  'TRPM6',
#  'AKR1A1',
#  'CCDC9',
#  'KLHL20',
#  'RHBDD2',
#  'LDHAL6A',
#  'DYRK1B',
#  'EPHA6',
#  'DACH1',
#  'PAIP2B',
#  'KCNK17',
#  'FASLG',
#  'GATA1',
#  'GJA4',
#  'ST18',
#  'HNRNPC',
#  'NUP214',
#  'TMEM213',
#  'TRIM63',
#  'HENMT1',
#  'ACBD5',
#  'HOXD13',
#  'MINOS1',
#  'AFAP1',
#  'ID1',
#  'PANK3',
#  'PPIB',
#  'SDHB',
#  'NR2C2',
#  'CXorf66',
#  'AKT1',
#  'PCDH15',
#  'PTGES3',
#  'INSC',
#  'USP10',
#  'IFNLR1',
#  'HYPK',
#  'RANBP10',
#  'C16orf92',
#  'ZG16',
#  'FRAT1',
#  'CPNE8',
#  'GPR85',
#  'DYNLRB2',
#  'MAEA',
#  'C8orf33',
#  'SNF8',
#  'ANKRD54',
#  'ARL14EP',
#  'SPRTN',
#  'LRRC63',
#  'NPNT',
#  'TMEFF1',
#  'MARVELD3',
#  'CDH17',
#  'MSH6',
#  'ITM2B',
#  'PRSS8',
#  'PTPN2',
#  'TMEM86B',
#  'GABRA1',
#  'PCNXL3',
#  'TEX22',
#  'AFF4',
#  'GORASP1',
#  'TIMMDC1',
#  'MLLT10',
#  'GJB5',
#  'PNPLA3',
#  'TBC1D9',
#  'SYNGAP1',
#  'HDHD2',
#  'ABI2',
#  'ATP8B4',
#  'MRPL36',
#  'NEU3',
#  'COL25A1',
#  'MLN',
#  'GYLTL1B',
#  'LEFTY1',
#  'HIST2H4A',
#  'C8orf59',
#  'C1D',
#  'SCAF1',
#  'CACNG3',
#  'SOX9',
#  'C11orf85',
#  'MAN1A2',
#  'GSTA3',
#  'ICAM2',
#  'MAP1LC3A',
#  'PAGE2',
#  'LRP1',
#  'GSPT2',
#  'MBOAT4',
#  'PCNXL2',
#  'PALMD',
#  'BRD8',
#  'TBC1D17',
#  'HNRNPK',
#  'PTPRM',
#  'IL9',
#  'BAGE4',
#  'CLEC9A',
#  'FXYD3',
#  'SLC7A11',
#  'CNDP2',
#  'CP',
#  'BTBD16',
#  'ECI1',
#  'PHAX',
#  'FAM188B',
#  'GPRIN1',
#  'TIPARP',
#  'BOLA3',
#  'RCAN1',
#  'TMEM176A',
#  'ATP2C2',
#  'DDX43',
#  'FKBP14',
#  'ANKRD36B',
#  'ITPR2',
#  'MOG',
#  'CDC16',
#  'GP5',
#  'HS3ST1',
#  'SLC20A1',
#  'CDX2',
#  'MOSPD2',
#  'MANF',
#  'CENPO',
#  'ABRA',
#  'CARS2',
#  'AKAP6',
#  'CLTB',
#  'SLC2A14',
#  'CEACAM8',
#  'UCMA',
#  'RNF122',
#  'GNPDA2',
#  'MYSM1',
#  'CA10',
#  'SNX6',
#  'MPPE1',
#  'PACSIN3',
#  'HCN2',
#  'ADPGK',
#  'TRIM44',
#  'RNF103',
#  'GGA1',
#  'YBX3',
#  'ZNF584',
#  'ATP1B2',
#  'CCPG1',
#  'SH2D2A',
#  'MRPL49',
#  'FBN1',
#  'C4orf22',
#  'LDB2',
#  'TNS3',
#  'IRF9',
#  'INTS9',
#  'GPR4',
#  'VIPR2',
#  'PRB4',
#  'PRM2',
#  'HEPH',
#  'BRCC3',
#  'ANKRD26',
#  'CEMIP',
#  'GATAD1',
#  'TLR9',
#  'KRTAP3-2',
#  'GABRA5',
#  'SFN',
#  'SLC41A3',
#  'FNTB',
#  'RASGEF1B',
#  'RTN4IP1',
#  'NEDD8',
#  'VAX2',
#  'MYO5A',
#  'FXYD6',
#  'PEG3',
#  'INA',
#  'ADARB2',
#  'RIMKLA',
#  'MON1A',
#  'C17orf70',
#  'ZNF226',
#  'UNG',
#  'AMOT',
#  'GKAP1',
#  'SLC35F4',
#  'COQ5',
#  'SLC46A1',
#  'DDX50',
#  'LMO4',
#  'INPP5J',
#  'AGR2',
#  'MYL3',
#  'C16orf74',
#  'SPIN2B',
#  'TLCD1',
#  'SCD5',
#  'ALDH1A1',
#  'FUBP3',
#  'GPR55',
#  'RPL7',
#  'GBP1',
#  'FER',
#  'SH2D1A',
#  'CAMSAP2',
#  'CYP2E1',
#  'DOCK9',
#  'CXCL16',
#  'MYT1L',
#  'FBXW7',
#  'NOC2L',
#  'XRCC4',
#  'TBCB',
#  'C9orf85',
#  'SDCBP2',
#  'FBXO16',
#  'MRPL53',
#  'EI24',
#  'TUBAL3',
#  'ITPK1',
#  'CLCA1',
#  'BRINP2',
#  'PPP2R1B',
#  'MOAP1',
#  'GABARAPL2',
#  'MAGEA8',
#  'MEA1',
#  'C11orf52',
#  'ZNF562',
#  'CPNE5',
#  'MTX1',
#  'NHLRC4',
#  'BCAS3',
#  'MITF',
#  'SEMA3E',
#  'ZNF324B',
#  'RNASE13',
#  'CCT6A',
#  'GCM2',
#  'JAM3',
#  'NKAIN4',
#  'PSMD4',
#  'ASF1A',
#  'NAMPT',
#  'IRS2',
#  'PGR',
#  'AKT2',
#  'TRMT10B',
#  'SYCN',
#  'MTMR7',
#  'RPL22L1',
#  'ACBD6',
#  'PRODH',
#  'SPOP',
#  'BMP2K',
#  'KLHL18',
#  'ARHGEF19',
#  'G3BP2',
#  'GAS1',
#  'MEX3C',
#  'MTMR1',
#  'G6PD',
#  'TMEM104',
#  'VLDLR',
#  'ALS2CL',
#  'SENP7',
#  'LIME1',
#  'OAZ1',
#  'ABCD1',
#  'RNASEH1',
#  'ARFIP1',
#  'CPSF7',
#  'PCIF1',
#  'GPR116',
#  'FBXW8',
#  'MBD3',
#  'PIK3AP1',
#  'PSMA3',
#  'PTPLB',
#  'SDC2',
#  'ATP5F1',
#  'ATP6V0A1',
#  'RGL4',
#  'TUBB1',
#  'VCL',
#  'ZFYVE16',
#  'CIC',
#  'CHST7',
#  'MYL9',
#  'ANGPTL5',
#  'FAM81A',
#  'IL12RB1',
#  'LAMTOR3',
#  'DGCR2',
#  'RECQL4',
#  'PREX1',
#  'ZNF777',
#  'CPA2',
#  'DPP6',
#  'ZNF616',
#  'RHBDL1',
#  'ZNF615',
#  'ACTC1',
#  'ITM2C',
#  'TPO',
#  'CCDC50',
#  'SLC4A1',
#  'SLC5A12',
#  'C1QTNF2',
#  'IL33',
#  'FUT3',
#  'YPEL3',
#  'CHST15',
#  'LRRIQ1',
#  'ERC1',
#  'PMPCA',
#  'SMURF2',
#  'GPALPP1',
#  'ANO4',
#  'FBRSL1',
#  'SLC22A3',
#  'VDAC2',
#  'ZNF580',
#  'CMTM5',
#  'TSN',
#  'CCDC102B',
#  'MSMP',
#  'AJAP1',
#  'C4BPB',
#  'C17orf66',
#  'COG3',
#  'DEPDC7',
#  'FAM47A',
#  'ITLN1',
#  'CLEC4D',
#  'LAT2',
#  'ALG9',
#  'PEX11A',
#  'PFDN2',
#  'UCP3',
#  'UNC119B',
#  'C4orf33',
#  'UBXN1',
#  'GPR17',
#  'XRCC6',
#  'HLA-E',
#  'EPB41L5',
#  'FAM170A',
#  'CDH9',
#  'CA1',
#  'FOLH1',
#  'SOX30',
#  'TGFB3',
#  'ZNF99',
#  'SERP1',
#  'ANKS3',
#  'GLCCI1',
#  'CSF2RA',
#  'KIAA1671',
#  'LRRC47',
#  'UNC93A',
#  'B3GAT1',
#  'CXorf27',
#  'EPRS',
#  'TESC',
#  'FBXO30',
#  'SCN9A',
#  'ABI1',
#  'DNAJC19',
#  'MYO1E',
#  'ARCN1',
#  'SMU1',
#  'LRG1',
#  'SKOR1',
#  'NR2F2',
#  'ARL15',
#  'NOP56',
#  'TMEM147',
#  'SCGB1D2',
#  'IER3',
#  'MTL5',
#  'SMTN',
#  'DHCR24',
#  'NRXN1',
#  'PAQR9',
#  'PDCD1LG2',
#  'STK32C',
#  'CACNG1',
#  'RDH13',
#  'ZBTB47',
#  'ZNF730',
#  'TMPRSS3',
#  'KDM5C',
#  'ABT1',
#  'MPP1',
#  'NME2',
#  'TARS2',
#  'MAST2',
#  'S1PR1',
#  'GSTM1',
#  'KCNQ2',
#  'TPM3',
#  'FZR1',
#  'PAQR3',
#  'ESYT1',
#  'HMOX1',
#  'RS1',
#  'GFPT2',
#  'RTN1',
#  'TRIM61',
#  'MARCH4',
#  'FAM71F1',
#  'TFAP4',
#  'VPS52',
#  'FAM150A',
#  'BAZ1A',
#  'RASL12',
#  'UBB',
#  'TRIQK',
#  'LOXL3',
#  'ZSCAN21',
#  'HPD',
#  'DNTTIP2',
#  'GABRG2',
#  'GSR',
#  'KIAA0141',
#  'PILRB',
#  'KIAA1377',
#  'SEC16B',
#  'HARBI1',
#  'GPR111',
#  'LYPD4',
#  'MGEA5',
#  'WBSCR28',
#  'PXYLP1',
#  'FAM155A',
#  'GET4',
#  'RBM11',
#  'TEX10',
#  'OTUD7B',
#  'ARHGEF11',
#  'MFSD10',
#  'MORC2',
#  'PDGFB',
#  'ACSF3',
#  'VIPR1',
#  'PHC1',
#  'LRAT',
#  'TXNDC5',
#  'CLTA',
#  'ISLR2',
#  'FAIM3',
#  'CNTD2',
#  'NSMAF',
#  'PARP1',
#  'ZNF74',
#  'MAPK8IP2',
#  'SUN2',
#  'SOX13',
#  'MBD2',
#  'PYGB',
#  'HNRNPA3',
#  'BBS5',
#  'C11orf1',
#  'DGKD',
#  'MOCS1',
#  'SLC35B1',
#  'TCTN3',
#  'TRIM67',
#  'ATP2A1',
#  'ZNF227',
#  'LAT',
#  'PRDX5',
#  'RTKN',
#  'IGFBP4',
#  'CASKIN2',
#  'SNAPIN',
#  'EEF1A2',
#  'PRUNE',
#  'GAB1',
#  'IQGAP2',
#  'LETM1',
#  'APOPT1',
#  'MSLN',
#  'NFE2L3',
#  'SH3TC1',
#  'ZBTB37',
#  'CUBN',
#  'MAFA',
#  'DNAJC6',
#  'MYOCD',
#  'LRRC7',
#  'ETF1',
#  'NDUFB9',
#  'CYFIP1',
#  'ZNF521',
#  'FGF20',
#  'TXNDC12',
#  'KCNAB1',
#  'CASP8',
#  'FAM20A',
#  'MORN4',
#  'ADAR',
#  'IL2RA',
#  'KATNA1',
#  'NHLRC1',
#  'CHRNB2',
#  'RPLP0',
#  'ATMIN',
#  'GOLT1A',
#  'PRSS3',
#  'ASCC3',
#  'PIGA',
#  'FAM180A',
#  'SREK1IP1',
#  'ZBTB42',
#  'REN',
#  'ADA',
#  'RC3H2',
#  'PEBP1',
#  'RPS6KL1',
#  'FBXL17',
#  'PPIH',
#  'PLA2G1B',
#  'DENND2D',
#  'STX12',
#  'ALDH3B1',
#  'TMEM57',
#  'GABPA',
#  'LPIN2',
#  'ARF4',
#  'C12orf75',
#  'ANKS6',
#  'WDR87',
#  'GPR87',
#  'OLAH',
#  'SCGB1D4',
#  'PCYOX1',
#  'TVP23C',
#  'OSR1',
#  'MYOF',
#  'SMARCAL1',
#  'MLH1',
#  'SCNM1',
#  'LYSMD4',
#  'PTF1A',
#  'HLA-C',
#  'SMYD5',
#  'NXNL1',
#  'C21orf33',
#  'GMEB2',
#  'LRRC52',
#  'NEK1',
#  'NET1',
#  'HDAC7',
#  'TREH',
#  'FAIM2',
#  'SYDE2',
#  'PLA2R1',
#  'WDR26',
#  'XPNPEP3',
#  'NPHP1',
#  'ACAA2',
#  'PTP4A3',
#  ...]

# %%
def get_ensembl_id(gene_symbol):
    url = f"https://rest.ensembl.org/xrefs/symbol/homo_sapiens/{gene_symbol}?content-type=application/json"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if isinstance(data, list) and len(data) > 0 and 'id' in data[0]:
            return data[0]['id']  # Ensembl Gene ID
    return None  # Return None if not found

def get_latest_hgnc_symbol(ensembl_id):
    url = f"https://rest.ensembl.org/lookup/id/{ensembl_id}?content-type=application/json"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if 'display_name' in data:
            return data['display_name']  # Latest HGNC Gene Symbol
    return None  # Return None if not found

def update_gene_symbols(old_symbols):
    results = []
    for symbol in old_symbols:
        ensembl_id = get_ensembl_id(symbol)
        new_symbol = get_latest_hgnc_symbol(ensembl_id) if ensembl_id else None
        results.append((symbol, ensembl_id, new_symbol))
    
    return pd.DataFrame(results, columns=['Old_Symbol', 'Ensembl_ID', 'Updated_Symbol'])

# Example usage
updated_symbols = update_gene_symbols(old_gene_symbols)
print(updated_symbols)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connection.py:208, in HTTPConnection._new_conn(self)
#     207 except SocketTimeout as e:
# --> 208     raise ConnectTimeoutError(
#     209         self,
#     210         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     211     ) from e
#     213 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x12b46c6d0>, 'Connection to rest.ensembl.org timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Max retries exceeded with url: /xrefs/symbol/homo_sapiens/CTDSP1?content-type=application/json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12b46c6d0>, 'Connection to rest.ensembl.org timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[4], line 31
#      28     return pd.DataFrame(results, columns=['Old_Symbol', 'Ensembl_ID', 'Updated_Symbol'])
#      30 # Example usage
# ---> 31 updated_symbols = update_gene_symbols(old_gene_symbols)
#      32 print(updated_symbols)
#
# Cell In[4], line 24, in update_gene_symbols(old_symbols)
#      22 results = []
#      23 for symbol in old_symbols:
# ---> 24     ensembl_id = get_ensembl_id(symbol)
#      25     new_symbol = get_latest_hgnc_symbol(ensembl_id) if ensembl_id else None
#      26     results.append((symbol, ensembl_id, new_symbol))
#
# Cell In[4], line 3, in get_ensembl_id(gene_symbol)
#       1 def get_ensembl_id(gene_symbol):
#       2     url = f"https://rest.ensembl.org/xrefs/symbol/homo_sapiens/{gene_symbol}?content-type=application/json"
# ----> 3     response = requests.get(url)
#       5     if response.status_code == 200:
#       6         data = response.json()
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/quarto_llm_env/lib/python3.11/site-packages/requests/adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Max retries exceeded with url: /xrefs/symbol/homo_sapiens/CTDSP1?content-type=application/json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12b46c6d0>, 'Connection to rest.ensembl.org timed out. (connect timeout=None)'))
